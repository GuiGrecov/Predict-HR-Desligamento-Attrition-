# %% [markdown]
# # 0. Import and Functions

# %% [markdown]
# ## 0.1 Import

# %%
import inflection


import pandas  as pd 
import seaborn as sns 
import plotly  as plt 
import numpy   as np 


from IPython.display      import Image

# %%
df_raw = pd.read_csv("datas/WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %% [markdown]
# ## 0.2 Functions

# %% [markdown]
# # 1. Data Describe

# %%
df1 = df_raw.copy()

# %%
df1.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# ## 1.1 Rename Columns

# %% [markdown]
# Explicação das colunas:
# <br>
#
# * Age - Idade
# * Attrition - Saída
# * BusinessTravel - Viagem a Trabalho
# * DailyRate - Diária
# * Department - Departamento
# * DistanceFromHome - Distância de Casa
# * Education - Educação
# * EducationField - Campo de Educação
# * EmployeeCount  -  Contagem de Empregados
# * EmployeeNumber -  Número de Empregado
# * EnvironmentSatisfaction - Satisfação da Empresa
# * Gender - Gênero
# * HourlyRate - Horas de Trabalho
# * JobInvolvement - Participação do Trbalho
# * JobLevel - Nível do Empregado
# * JobRole  - Cargo
# * JobSatisfaction - Satisfação do Trabalho
# * MaritalStatus   - Estado Civil
# * MonthlyIncome   - Renda Mensal
# * MonthlyRate     - Taxa Mensal
# * NumCompaniesWorked  -  Número de Ex Empresas
# * Over18   -  Mais de 18 anos
# * OverTime  - Ao longo do tempo
# * PercentSalaryHike   - Percentual de Salário
# * PerformanceRating  - Avaliação de Desempenho
# * RelationshipSatisfaction   - Satisfação de Relacionamento
# * StandardHours - Horas Padrão
# * StockOptionLevel - Level das Ações
# * TotalWorkingYears - Anos trabalhados
# * TrainingTimesLastYear - Horas de Treinamento Ano Passado
# * WorkLifeBalance       - Equilíbrio Entre vida Pessoal
# * YearsAtCompany        - Anos de Empresa
# * YearsInCurrentRole    - Anos no mesmo cargo
# * YearsSinceLastPromotion - Anos desde a última promoção
# * YearsWithCurrManager    - Anos com gerente atual

# %%
cols_old = ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
       'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']

snakecase = lambda x: inflection.underscore( x )

cols_new = list( map( snakecase, cols_old ) )

# rename
df1.columns = cols_new

# %% [markdown]
# ## 1.2 Data Dimensions

# %%
print( 'Number of Rows: {}'.format( df1.shape[0] ) )
print( 'Number of Cols: {}'.format( df1.shape[1] ) )
# Out:
# Number of Rows: 1470
# Number of Cols: 35

# %% [markdown]
# ## 1.3 Data Types

# %%
df1.dtypes
# Out:
# age                            int64
# attrition                     object
# business_travel               object
# daily_rate                     int64
# department                    object
# distance_from_home             int64
# education                      int64
# education_field               object
# employee_count                 int64
# employee_number                int64
# environment_satisfaction       int64
# gender                        object
# hourly_rate                    int64
# job_involvement                int64
# job_level                      int64
# job_role                      object
# job_satisfaction               int64
# marital_status                object
# monthly_income                 int64
# monthly_rate                   int64
# num_companies_worked           int64
# over18                        object
# over_time                     object
# percent_salary_hike            int64
# performance_rating             int64
# relationship_satisfaction      int64
# standard_hours                 int64
# stock_option_level             int64
# total_working_years            int64
# training_times_last_year       int64
# work_life_balance              int64
# years_at_company               int64
# years_in_current_role          int64
# years_since_last_promotion     int64
# years_with_curr_manager        int64
# dtype: object

# %%
df1
# Out:
#       age attrition    business_travel  daily_rate              department  \
# 0      41       Yes      Travel_Rarely        1102                   Sales
# 1      49        No  Travel_Frequently         279  Research & Development
# 2      37       Yes      Travel_Rarely        1373  Research & Development
# 3      33        No  Travel_Frequently        1392  Research & Development
# 4      27        No      Travel_Rarely         591  Research & Development
# ...   ...       ...                ...         ...                     ...
# 1465   36        No  Travel_Frequently         884  Research & Development
# 1466   39        No      Travel_Rarely         613  Research & Development
# 1467   27        No      Travel_Rarely         155  Research & Development
# 1468   49        No  Travel_Frequently        1023                   Sales
# 1469   34        No      Travel_Rarely         628  Research & Development
#
#       distance_from_home  education education_field  employee_count  \
# 0                      1          2   Life Sciences               1
# 1                      8          1   Life Sciences               1
# 2                      2          2           Other               1
# 3                      3          4   Life Sciences               1
# 4                      2          1         Medical               1
# ...                  ...        ...             ...             ...
# 1465                  23          2         Medical               1
# 1466                   6          1         Medical               1
# 1467                   4          3   Life Sciences               1
# 1468                   2          3         Medical               1
# 1469                   8          3         Medical               1
#
#       employee_number  ...  relationship_satisfaction standard_hours  \
# 0                   1  ...                          1             80
# 1                   2  ...                          4             80
# 2                   4  ...                          2             80
# 3                   5  ...                          3             80
# 4                   7  ...                          4             80
# ...               ...  ...                        ...            ...
# 1465             2061  ...                          3             80
# 1466             2062  ...                          1             80
# 1467             2064  ...                          2             80
# 1468             2065  ...                          4             80
# 1469             2068  ...                          1             80
#
#       stock_option_level  total_working_years  training_times_last_year  \
# 0                      0                    8                         0
# 1                      1                   10                         3
# 2                      0                    7                         3
# 3                      0                    8                         3
# 4                      1                    6                         3
# ...                  ...                  ...                       ...
# 1465                   1                   17                         3
# 1466                   1                    9                         5
# 1467                   1                    6                         0
# 1468                   0                   17                         3
# 1469                   0                    6                         3
#
#      work_life_balance  years_at_company years_in_current_role  \
# 0                    1                 6                     4
# 1                    3                10                     7
# 2                    3                 0                     0
# 3                    3                 8                     7
# 4                    3                 2                     2
# ...                ...               ...                   ...
# 1465                 3                 5                     2
# 1466                 3                 7                     7
# 1467                 3                 6                     2
# 1468                 2                 9                     6
# 1469                 4                 4                     3
#
#       years_since_last_promotion  years_with_curr_manager
# 0                              0                        5
# 1                              1                        7
# 2                              0                        0
# 3                              3                        0
# 4                              2                        2
# ...                          ...                      ...
# 1465                           0                        3
# 1466                           1                        7
# 1467                           0                        3
# 1468                           0                        8
# 1469                           1                        2
#
# [1470 rows x 35 columns]

# %% [markdown]
# ## 1.5 Change DataTypes

# %%
df1["job_satisfaction"].value_counts()
# Out:
# 4    459
# 3    442
# 1    289
# 2    280
# Name: job_satisfaction, dtype: int64

# %%
df1["job_satisfaction1"] = df1["job_satisfaction"].apply(lambda x: "ruim"  if x == 1 else 
                                                       "regular" if x == 2 else 
                                                        "bom" if x == 3 else 
                                                        "excelente")

df1["performance_rating1"] = df1["performance_rating"].apply(lambda x: "ruim"  if x == 1 else 
                                                       "regular" if x == 2 else 
                                                        "bom" if x == 3 else 
                                                        "excelente")


df1["environment_satisfaction1"] = df1["environment_satisfaction"].apply(lambda x: "ruim"  if x == 1 else 
                                                       "regular" if x == 2 else 
                                                        "bom" if x == 3 else 
                                                        "excelente")

# %% [markdown]
# ## 1.6 Descriptive Statistics

# %%
num_attributes = df1.select_dtypes(exclude='object')
cat_attributes = df1.select_dtypes(include='object')

# %% [markdown]
# ### 1.6.1 Numerical Atributes

# %%
num_attributes = num_attributes.drop(columns=['employee_number'], axis=1) 

describe = num_attributes.describe().T

describe['range'] = (num_attributes.max() - num_attributes.min()).tolist()
describe['variation coefficient'] = (num_attributes.std() / num_attributes.mean()).tolist()
describe['skew'] = num_attributes.skew().tolist()
describe['kurtosis'] = num_attributes.kurtosis().tolist()

describe
# Out:
#                              count          mean          std     min     25%  \
# age                         1470.0     36.923810     9.135373    18.0    30.0
# daily_rate                  1470.0    802.485714   403.509100   102.0   465.0
# distance_from_home          1470.0      9.192517     8.106864     1.0     2.0
# education                   1470.0      2.912925     1.024165     1.0     2.0
# employee_count              1470.0      1.000000     0.000000     1.0     1.0
# environment_satisfaction    1470.0      2.721769     1.093082     1.0     2.0
# hourly_rate                 1470.0     65.891156    20.329428    30.0    48.0
# job_involvement             1470.0      2.729932     0.711561     1.0     2.0
# job_level                   1470.0      2.063946     1.106940     1.0     1.0
# job_satisfaction            1470.0      2.728571     1.102846     1.0     2.0
# monthly_income              1470.0   6502.931293  4707.956783  1009.0  2911.0
# monthly_rate                1470.0  14313.103401  7117.786044  2094.0  8047.0
# num_companies_worked        1470.0      2.693197     2.498009     0.0     1.0
# percent_salary_hike         1470.0     15.209524     3.659938    11.0    12.0
# performance_rating          1470.0      3.153741     0.360824     3.0     3.0
# relationship_satisfaction   1470.0      2.712245     1.081209     1.0     2.0
# standard_hours              1470.0     80.000000     0.000000    80.0    80.0
# stock_option_level          1470.0      0.793878     0.852077     0.0     0.0
# total_working_years         1470.0     11.279592     7.780782     0.0     6.0
# training_times_last_year    1470.0      2.799320     1.289271     0.0     2.0
# work_life_balance           1470.0      2.761224     0.706476     1.0     2.0
# years_at_company            1470.0      7.008163     6.126525     0.0     3.0
# years_in_current_role       1470.0      4.229252     3.623137     0.0     2.0
# years_since_last_promotion  1470.0      2.187755     3.222430     0.0     0.0
# years_with_curr_manager     1470.0      4.123129     3.568136     0.0     2.0
#
#                                 50%       75%      max  range  \
# age                            36.0     43.00     60.0     42
# daily_rate                    802.0   1157.00   1499.0   1397
# distance_from_home              7.0     14.00     29.0     28
# education                       3.0      4.00      5.0      4
# employee_count                  1.0      1.00      1.0      0
# environment_satisfaction        3.0      4.00      4.0      3
# hourly_rate                    66.0     83.75    100.0     70
# job_involvement                 3.0      3.00      4.0      3
# job_level                       2.0      3.00      5.0      4
# job_satisfaction                3.0      4.00      4.0      3
# monthly_income               4919.0   8379.00  19999.0  18990
# monthly_rate                14235.5  20461.50  26999.0  24905
# num_companies_worked            2.0      4.00      9.0      9
# percent_salary_hike            14.0     18.00     25.0     14
# performance_rating              3.0      3.00      4.0      1
# relationship_satisfaction       3.0      4.00      4.0      3
# standard_hours                 80.0     80.00     80.0      0
# stock_option_level              1.0      1.00      3.0      3
# total_working_years            10.0     15.00     40.0     40
# training_times_last_year        3.0      3.00      6.0      6
# work_life_balance               3.0      3.00      4.0      3
# years_at_company                5.0      9.00     40.0     40
# years_in_current_role           3.0      7.00     18.0     18
# years_since_last_promotion      1.0      3.00     15.0     15
# years_with_curr_manager         3.0      7.00     17.0     17
#
#                             variation coefficient      skew  kurtosis
# age                                      0.247411  0.413286 -0.404145
# daily_rate                               0.502824 -0.003519 -1.203823
# distance_from_home                       0.881898  0.958118 -0.224833
# education                                0.351593 -0.289681 -0.559115
# employee_count                           0.000000  0.000000  0.000000
# environment_satisfaction                 0.401607 -0.321654 -1.202521
# hourly_rate                              0.308530 -0.032311 -1.196398
# job_involvement                          0.260652 -0.498419  0.270999
# job_level                                0.536322  1.025401  0.399152
# job_satisfaction                         0.404184 -0.329672 -1.222193
# monthly_income                           0.723975  1.369817  1.005233
# monthly_rate                             0.497292  0.018578 -1.214956
# num_companies_worked                     0.927525  1.026471  0.010214
# percent_salary_hike                      0.240635  0.821128 -0.300598
# performance_rating                       0.114411  1.921883  1.695939
# relationship_satisfaction                0.398640 -0.302828 -1.184814
# standard_hours                           0.000000  0.000000  0.000000
# stock_option_level                       1.073310  0.968980  0.364634
# total_working_years                      0.689811  1.117172  0.918270
# training_times_last_year                 0.460566  0.553124  0.494993
# work_life_balance                        0.255856 -0.552480  0.419460
# years_at_company                         0.874198  1.764529  3.935509
# years_in_current_role                    0.856685  0.917363  0.477421
# years_since_last_promotion               1.472939  1.984290  3.612673
# years_with_curr_manager                  0.865395  0.833451  0.171058

# %% [markdown]
# * ANÁLISE
#
# **nenhum dos nossos dados são homogêneos. nenhum tem variation coefficient menor do que 15%**
#
# age (idade): <br>
# + em média: 37 anos. Com skew positivo - concentração de dados para valores mais baixos.
#
# distancefromhome: <br>
# + skew positiva, concentração para pessoas morando mais perto. Em média 9 km, um pouco longe.
#
#
# total_working_years: <br>
# + em média temos funcionários com 11 anos trabalhados número interessante
#
#
# num_companies_worked: <br>
# + em média os colaboradores trabalharam em 3 empresas, porém o nosso coeficiente é muito alto isso demonstra uma alta variação de dados.
#
# stock_option_level: <br>
# + alta variação de dados

# %% [markdown]
# ### 1.6.2 Categorical Atributes

# %%
cat_attributes
# Out:
#      attrition    business_travel              department education_field  \
# 0          Yes      Travel_Rarely                   Sales   Life Sciences
# 1           No  Travel_Frequently  Research & Development   Life Sciences
# 2          Yes      Travel_Rarely  Research & Development           Other
# 3           No  Travel_Frequently  Research & Development   Life Sciences
# 4           No      Travel_Rarely  Research & Development         Medical
# ...        ...                ...                     ...             ...
# 1465        No  Travel_Frequently  Research & Development         Medical
# 1466        No      Travel_Rarely  Research & Development         Medical
# 1467        No      Travel_Rarely  Research & Development   Life Sciences
# 1468        No  Travel_Frequently                   Sales         Medical
# 1469        No      Travel_Rarely  Research & Development         Medical
#
#       gender                   job_role marital_status over18 over_time  \
# 0     Female            Sales Executive         Single      Y       Yes
# 1       Male         Research Scientist        Married      Y        No
# 2       Male      Laboratory Technician         Single      Y       Yes
# 3     Female         Research Scientist        Married      Y       Yes
# 4       Male      Laboratory Technician        Married      Y        No
# ...      ...                        ...            ...    ...       ...
# 1465    Male      Laboratory Technician        Married      Y        No
# 1466    Male  Healthcare Representative        Married      Y        No
# 1467    Male     Manufacturing Director        Married      Y       Yes
# 1468    Male            Sales Executive        Married      Y        No
# 1469    Male      Laboratory Technician        Married      Y        No
#
#      job_satisfaction1 performance_rating1 environment_satisfaction1
# 0            excelente                 bom                   regular
# 1              regular           excelente                       bom
# 2                  bom                 bom                 excelente
# 3                  bom                 bom                 excelente
# 4              regular                 bom                      ruim
# ...                ...                 ...                       ...
# 1465         excelente                 bom                       bom
# 1466              ruim                 bom                 excelente
# 1467           regular           excelente                   regular
# 1468           regular                 bom                 excelente
# 1469               bom                 bom                   regular
#
# [1470 rows x 12 columns]

# %%
cat_attributes['job_satisfaction1'].value_counts(normalize=True)
# Out:
# excelente    0.312245
# bom          0.300680
# ruim         0.196599
# regular      0.190476
# Name: job_satisfaction1, dtype: float64

# %%
df1
# Out:
#       age attrition    business_travel  daily_rate              department  \
# 0      41       Yes      Travel_Rarely        1102                   Sales
# 1      49        No  Travel_Frequently         279  Research & Development
# 2      37       Yes      Travel_Rarely        1373  Research & Development
# 3      33        No  Travel_Frequently        1392  Research & Development
# 4      27        No      Travel_Rarely         591  Research & Development
# ...   ...       ...                ...         ...                     ...
# 1465   36        No  Travel_Frequently         884  Research & Development
# 1466   39        No      Travel_Rarely         613  Research & Development
# 1467   27        No      Travel_Rarely         155  Research & Development
# 1468   49        No  Travel_Frequently        1023                   Sales
# 1469   34        No      Travel_Rarely         628  Research & Development
#
#       distance_from_home  education education_field  employee_count  \
# 0                      1          2   Life Sciences               1
# 1                      8          1   Life Sciences               1
# 2                      2          2           Other               1
# 3                      3          4   Life Sciences               1
# 4                      2          1         Medical               1
# ...                  ...        ...             ...             ...
# 1465                  23          2         Medical               1
# 1466                   6          1         Medical               1
# 1467                   4          3   Life Sciences               1
# 1468                   2          3         Medical               1
# 1469                   8          3         Medical               1
#
#       employee_number  ...  total_working_years training_times_last_year  \
# 0                   1  ...                    8                        0
# 1                   2  ...                   10                        3
# 2                   4  ...                    7                        3
# 3                   5  ...                    8                        3
# 4                   7  ...                    6                        3
# ...               ...  ...                  ...                      ...
# 1465             2061  ...                   17                        3
# 1466             2062  ...                    9                        5
# 1467             2064  ...                    6                        0
# 1468             2065  ...                   17                        3
# 1469             2068  ...                    6                        3
#
#       work_life_balance  years_at_company  years_in_current_role  \
# 0                     1                 6                      4
# 1                     3                10                      7
# 2                     3                 0                      0
# 3                     3                 8                      7
# 4                     3                 2                      2
# ...                 ...               ...                    ...
# 1465                  3                 5                      2
# 1466                  3                 7                      7
# 1467                  3                 6                      2
# 1468                  2                 9                      6
# 1469                  4                 4                      3
#
#      years_since_last_promotion  years_with_curr_manager job_satisfaction1  \
# 0                             0                        5         excelente
# 1                             1                        7           regular
# 2                             0                        0               bom
# 3                             3                        0               bom
# 4                             2                        2           regular
# ...                         ...                      ...               ...
# 1465                          0                        3         excelente
# 1466                          1                        7              ruim
# 1467                          0                        3           regular
# 1468                          0                        8           regular
# 1469                          1                        2               bom
#
#       performance_rating1  environment_satisfaction1
# 0                     bom                    regular
# 1               excelente                        bom
# 2                     bom                  excelente
# 3                     bom                  excelente
# 4                     bom                       ruim
# ...                   ...                        ...
# 1465                  bom                        bom
# 1466                  bom                  excelente
# 1467            excelente                    regular
# 1468                  bom                  excelente
# 1469                  bom                    regular
#
# [1470 rows x 38 columns]

# %%
cat_attributes['environment_satisfaction1'].value_counts(normalize=True)
# Out:
# bom          0.308163
# excelente    0.303401
# regular      0.195238
# ruim         0.193197
# Name: environment_satisfaction1, dtype: float64

# %%
cat_attributes['performance_rating1'].value_counts()
# Out:
# bom          1244
# excelente     226
# Name: performance_rating1, dtype: int64

# %%
cat_attributes['attrition'].value_counts(normalize = True)
# Out:
# No     0.838776
# Yes    0.161224
# Name: attrition, dtype: float64

# %%
cat_attributes['business_travel'].value_counts(normalize=True)
# Out:
# Travel_Rarely        0.709524
# Travel_Frequently    0.188435
# Non-Travel           0.102041
# Name: business_travel, dtype: float64

# %%
cat_attributes['department'].value_counts(normalize=True)
# Out:
# Research & Development    0.653741
# Sales                     0.303401
# Human Resources           0.042857
# Name: department, dtype: float64

# %%
cat_attributes['education_field'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: education_field, dtype: int64

# %%
cat_attributes['gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: gender, dtype: int64

# %%
cat_attributes['marital_status'].value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: marital_status, dtype: int64

# %%
cat_attributes['job_role'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: job_role, dtype: int64

# %% [markdown]
# **INTEPRETAÇÃO**
# * job_satisfaction1 - temos maior concentração em bom e excelente
# * performance_rating1 -  não temos dados diferentes de bom e excelente
# * department - Research & Development é o maior concentração de 65% da amostra
# * business_travel - quase 70% viajam raramente
# * attrition - só temos 16% dos colaboradores desligados

# %% [markdown]
# # 2.Feature Engineering e Hipóteses

# %%
df2 = df1.copy()

# %% [markdown]
# ## 2.1 Mapa Mental para Hipóteses

# %%
Image("datas/img.png")
